# %%
using Plots
using LinearAlgebra
using Krylov
using Printf
using LaTeXStrings
using BenchmarkTools
include("poisson2d.jl")

# %%
default(lw=2, markersize=6,
    xtickfont=font(12), ytickfont=font(12),
    guidefont=font(14), legendfont=font(12), titlefont=font(12))

# %% [markdown]
# # Poisson Equation Example
# Solve
# $$
# -\Delta u = f
# $$
# over $(0,L_x)\times (0,L_y)$ with zero Dirichlet boundary conditions.
#
# Test with the eigenfunctions
# $$
# u = \sin(k_x \pi/L_x x)\sin(k_y \pi y/L_y)
# $$
# where $k_x,k_y\in \mathbb{Z}$, since these satisfy the boudnary conditions and
# $$
# -\Delta u = [(k_x \pi/L_x)^2 + (k_y\pi/L_y)^2] u
# $$

# %%
Lx = 1;
Ly = 1;
nx = 20; # (nx-1)×(ny-1) interior points
ny = 20;
Nx = nx-1;
Ny = ny-1;

x = LinRange(0, Lx, nx + 1)
y = LinRange(0, Ly, ny + 1)

@show Δx = x[2] - x[1];
@show Δy = y[2] - y[1];


xy = [[x_, y_] for x_ in x, y_ in y]; # mesh including boundary points
xy_int = [[x_, y_] for x_ in x[2:end-1],y_ in y[2:end-1]]; # interior mesh points

# %%
A = assemble_laplacian2d(Δx, Δy, Nx, Ny);

# %%
Matrix(A)

# %%
L = dirichlet_laplacian_2d_kron(Δx, Δy, Nx, Ny);
A = -L;

# %%
Matrix(L-A)

# %%
@show norm(L-A)

# %%
findall(Matrix(L-A).>0)

# %%
L[28,:]

# %%
Nx * Ny

# %%
A[36,:]

# %%
for k in 1:Nx*Ny
    j, i = fldmod1(k, Nx)
    @printf("[%d] i=%d, j=%d\n", k, i, j)
end

# %%
k = 4
j, i = fldmod1(k, Nx)

# %%
[1 + (Ny - 2) * Nx, 1 + (Ny - 1) * Nx, 2 + (Ny - 1) * Nx]

# %%
Ny

# %%
A[4,:]

# %%
Matrix(L-A)

# %%
ex = ones(Nx)
Tx = spdiagm(
    -1 => ex[1:end-1],
        0 => -2 .* ex,
        1 => ex[1:end-1]
) / Δx^2

# 1D Dirichlet Laplacian in y
ey = ones(Ny)
Ty = spdiagm(
    -1 => ey[1:end-1],
        0 => -2 .* ey,
        1 => ey[1:end-1]
) / Δy^2

Ix = sparse(I, Nx, Nx)
Iy = sparse(I, Ny, Ny)

# 2D Laplacian
# L = kron(Iy, Tx) + kron(Ty, Ix)
L = kron(Tx, Iy) + kron(Ix,Ty)

# %%
Matrix(L)

# %%
Matrix(L-A)

# %%
findall(Matrix(L-A).>0)

# %%
L[4,8]

# %%
A[4,8]

# %%
L[4,:]

# %%
A[4,:]

# %%
Matrix(L+A)[9,18]

# %%
Matrix(L)

# %%
fldmod1(50, nx)

# %%
nx*(3-1) + 12

# %%
kx = 3;
ky = 2;
# X = (x,y) in 2D
u_exact = X -> sin(kx * π * X[1] / Lx) * sin(ky * π * X[2] / Ly);
f = X -> ((kx * π / Lx)^2 + (ky * π / Ly)^2) * u_exact(X);

# %%
B = f.(xy_int)[:]; # flattern into a column vector

# %%
contourf(x, y, u_exact.(xy)')# note use of transpose;
xlabel!(L"$x$")
ylabel!(L"$y$")
title!(L"Exact Solution, $u$")

# %%
contourf(x, y, f.(xy)')# note use of transpose;
xlabel!(L"$x$")
ylabel!(L"$y$")
title!(L"Data, $f$")

# %%
U = A \ B;
u = reshape(U, Nx, Ny); # get as a 2D array

# %%
contourf(x[2:end-1], y[2:end-1], u')

# %%
contourf(x[2:end-1], y[2:end-1], u_exact.(xy_int)')# note use of transpose;
xlabel!(L"$x$")
ylabel!(L"$y$")
title!(L"Exact Solution, $u$")

# %%
contourf(x[2:end-1], y[2:end-1], u' .- u_exact.(xy_int)')

# %%
surface(x[2:end-1], y[2:end-1], u')

# %%
err = norm(U .- u_exact.(xy_int)[:], Inf);
println("Error = ", err)

# %% [markdown]
# # Timing and Error

# %%
function poisson_solve(n, kx=1, ky=1)
    Lx = 1
    Ly = 1
    nx = n 
    ny = n
    x = LinRange(0, Lx, nx + 2)
    y = LinRange(0, Ly, ny + 2)

    Δx = x[2] - x[1]
    Δy = y[2] - y[1]

    kx = 1
    ky = 1
    u_exact = X -> sin(kx * π * X[1] / Lx) * sin(ky * π * X[2] / Ly)
    f = X -> ((kx * π / Lx)^2 + (ky * π / Ly)^2) * sin(kx * π * X[1] / Lx) * sin(ky * π * X[2] / Ly)
    xy_int = [[x_, y_] for x_ in x[2:end-1],y_ in y[2:end-1]]; # interior mesh points
    B = f.(xy_int)[:] # flattern into a column vector
    A = assemble_laplacian2d(Δx, Δy, nx, ny)
    U = A \ B
    err = norm(U .- u_exact.(xy_int)[:], Inf)
    return err
end

# %%
n_vals = [10, 20, 40, 80, 160, 320];
for n in n_vals
    @btime poisson_solve($n);
end

# %%
function poisson_solve_krylov(n, kx=1, ky=1)
    Lx = 1
    Ly = 1
    nx = n
    ny = n
    x = LinRange(0, Lx, nx + 1)
    y = LinRange(0, Ly, ny + 1)
    Nx = nx - 1
    Ny = ny - 1

    Δx = x[2] - x[1]
    Δy = y[2] - y[1]

    kx = 1
    ky = 1
    u_exact = X -> sin(kx * π * X[1] / Lx) * sin(ky * π * X[2] / Ly)
    f = X -> ((kx * π / Lx)^2 + (ky * π / Ly)^2) * sin(kx * π * X[1] / Lx) * sin(ky * π * X[2] / Ly)
    xy_int = [[x_, y_] for x_ in x[2:end-1],y_ in y[2:end-1]]; # interior mesh points
    B = f.(xy_int)[:] # flattern into a column vector
    # A = assemble_laplacian2d(Δx, Δy, nx, ny)
    A = -dirichlet_laplacian_2d_kron(Δx, Δy, Nx, Ny)
    U, _= cg(A, B)
    err = norm(U .- u_exact.(xy_int)[:], Inf)
    return err
end

# %%
n_vals = [10, 20, 40, 80, 160, 320];
for n in n_vals
    @btime poisson_solve_krylov($n)
end

# %%
err_vals = Float64[];
for n in n_vals
    push!(err_vals, poisson_solve(n))
end

# %%
n_vals = [10, 20, 40, 80, 160, 320];
err_vals = Float64[];
for n in n_vals
    push!(err_vals, poisson_solve_krylov(n))
end

# %%
scatter(1 ./ n_vals, err_vals, 
    xscale=:log10, yscale=:log10, label="Error")
plot!(1 ./ n_vals, 1 ./ n_vals .^ 2, 
    label=L"$\propto \Delta x^2$")
xlabel!(L"$\Delta x$")

# %%
    Nx = 4;
    Nx = 5;

    
    ex = ones(Nx)
    Tx = spdiagm(
        -1 => ex[1:end-1],
         0 => -2 .* ex,
         1 => ex[1:end-1]
    ) / Δx^2

    # 1D Dirichlet Laplacian in y
    ey = ones(Ny)
    Ty = spdiagm(
        -1 => ey[1:end-1],
         0 => -2 .* ey,
         1 => ey[1:end-1]
    ) / Δy^2

    Ix = sparse(I, Nx, Nx)
    Iy = sparse(I, Ny, Ny)

    # 2D Laplacian
    # L = kron(Iy, Tx) + kron(Ty, Ix)

# %%
Matrix(kron(Iy, Tx))

# %%
Matrix(kron(Ty, Ix))
